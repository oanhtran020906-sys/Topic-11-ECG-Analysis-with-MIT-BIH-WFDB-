# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
from src.data_loader import load_ecg_record

ecg_series, fs = load_ecg_record("100")

print("Sampling rate:", fs)
ecg_series.head()
# Out:
# Sampling rate: 360
# 0 days 00:00:00             -0.145
# 0 days 00:00:00.002777778   -0.145
# 0 days 00:00:00.005555556   -0.145
# 0 days 00:00:00.008333333   -0.145
# 0 days 00:00:00.011111111   -0.145
# dtype: float64
